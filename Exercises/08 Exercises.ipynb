# %% [markdown]
# Import the NumPy and Matplotlib modules:

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 08.1 (function plotting)
#
# Consider the function
# $$
# f(x) = e^{x/10} \sin(\omega_{1}x)\sin(\omega_{0}x)
# $$
# from $x = -4\pi$ to $x = 4\pi$.

# %% [markdown]
# (1) Plot the function when $\omega_{0} = \omega_{1} = 1$. Label the axes.

# %%
num_points = 100
x = np.linspace(-4 * np.pi, 4 * np.pi, num=num_points)

f = np.exp(x / 10) * np.sin(x) * np.sin(x)

plt.plot(x, f)

# %% [markdown]
# (2) Create an interactive plot with sliders for $\omega_{0}$ and $\omega_{1}$, varying from 0 to 2.

# %%
from ipywidgets import interact
x = np.linspace(-4 * np.pi, 4 * np.pi, num=num_points)
def compute_f(x, omega0=1.0, omega1=1.0):
    return np.exp(x / 10) * np.sin(omega0 * x) * np.sin(omega1 * x)

def plot_f(omega0=1.0, omega1=1.0):
    plt.plot(x, compute_f(x, omega0, omega1))
    plt.show()

interact(plot_f, omega0=(0.0, 2.0, 0.01), omega1=(0.0, 2.0, 0.01))
# Out:
# interactive(children=(FloatSlider(value=1.0, description='omega0', max=2.0, step=0.01), FloatSlider(value=1.0,…
# <function __main__.plot_f(omega0=1.0, omega1=1.0)>

# %% [markdown]
# ## Exercise 08.2 (multiple function plotting)
#
# Plot the function
#
# $$
# f(x)  = \frac{\sin(x)}{x}
# $$
#
# from $x = -6\pi$ to $x = 6\pi$. Think carefully about which $x$ values you use when
# $x$ is close to zero.
#
# Add to the above plot the graph of $1/ \left| x \right|$, and limit the range of the $y$ axis to 1 using
# `plt.ylim`. (Hint: use `np.abs(x)` to return the absolute values of each
# component of a NumPy array `x`.)

# %%
x = np.linspace(-6 * np.pi, 6 * np.pi, num=num_points)
f = np.sin(x) / x
g = 1 / np.abs(x)

plt.plot(x, f)
plt.plot(x, g)
plt.ylim(-1.0, 1.0)
# Out:
# (-1.0, 1.0)

# %% [markdown]
# ## Exercise 08.3 (demographics and interactive plotting)
#
# A county planning body has requested an interactive tool to visualise the population distribution in Cambridgeshire (by district) from 2021 to 2031 for different population growth rate scenarios in each district. It can be assumed that:
#
# - the growth rates are constant in each district;
# - the annual growth rate in any one district shall be between -10% and 10%.
#
# Building on the pie chart example with population data in the Activity notebook, create an interactive plot with:
#
# 1. A slider for the year (from 2021 to 2031); and
# 2. Sliders for the annual population growth for each district (in percentage), with an
#    initial value of zero for each district.

# %% [markdown]
# ### Solution
#
# There are number of ways this exercise could be done, from very simple but not very robust with respect to changes in the order of the input data, to quite techical but robust with repsect to the order in which data is entered.

# %%
from ipywidgets import interact
# List of (district, population) data (in 2021)
population_data = (('Cambridge City', 148500), 
                   ('East Cambridgeshire', 92630), 
                   ('Fenland', 107630), 
                   ('Huntingdonshire', 189440), 
                   ('South Cambridgeshire', 169800))

# print(district)
# print(population)

colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'red']
explode = (0.1, 0.0, 0, 0, 0)  

def growth(data, year = 2021):
    district = [i[0] for i in data]    
    population = [i[1] for i in data]
    for i in range(len(population)):
        population[i] = population[i] * (1 + np.random.uniform(-0.1, 0.1))

    return district, population

    

def plot_f(year = 2021):
    district, population = growth(population_data, year)
    plt.pie(population, explode=explode, labels=district, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=90)    
    plt.title("2011 population distribution in Cambridgeshire")
    plt.show()

interact(plot_f, year=(2021, 2031, 1))
# Out:
# interactive(children=(IntSlider(value=2021, description='year', max=2031, min=2021), Output()), _dom_classes=(…
# <function __main__.plot_f(year=2021)>

# %% [markdown]
# ## Exercise 08.4 (crime reports by location)
#
# ### Background
#
# Your task is to produce a crime report data plot in the neighborhood of your college, by reported crime
# category.
#
# We can get crime data in the UK from the police data systems using what is known as a *REST API*,
# and turn the data into a `list` of Python dictionaries. Each entry in the list is a police report
# (an entry is a Python dictionary detailing the report).
#
# The first step is to import the modules we will be using:

# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\jy\appdata\roaming\python\python313\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jy\appdata\roaming\python\python313\site-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jy\appdata\roaming\python\python313\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jy\appdata\roaming\python\python313\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jy\appdata\roaming\python\python313\site-packages (from requests) (2025.10.5)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
import requests

# %% [markdown]
# The service https://data.police.uk has an interface where we can add specific strings to the URL (web address) to define what data we are intersted in, and the police server will return our requested data. The format is
#
#     https://data.police.uk/api/crimes-street/all-crime?lat=52.629729&lng=-1.131592&date=2025-05
#
# This return crimes reports within a one mile radius of the geographic coordinate point for the month `2025-03`.
#
# Below we create this URL string to include a part of the Cambridge city centre. You can modify this for your own college or other areas of interest (Google Maps is a handy way to get the geographic coordinates).

# %%
# A point in the Cambridge city centre (change this to your college)
lat, long = 52.205277, 0.119117

# year-month of interest
year_month = '2025-05'

# Construct request URL string
url = f"https://data.police.uk/api/crimes-street/all-crime?lat={lat}&lng={long}&date={year_month}"

# Fetch data from https://data.police.uk
r = requests.get(url)

# Check that data retrival was successful
r.raise_for_status()

# %% [markdown]
# The following converts the fetched data into a `list` of Python dictionaries:

# %%
crime_data = r.json()

# %% [markdown]
# To get an idea of how the data is arranged, we can look at the first report in the list. To make the displayed data easier to read, we use the 'pretty print' module `pprint`.

# %%
import pprint
if crime_data:
    pprint.pprint(crime_data[0])
    pprint.pprint(crime_data)
# Out:
# {'category': 'anti-social-behaviour',
#  'context': '',
#  'id': 127923315,
#  'location': {'latitude': '52.207966',
#               'longitude': '0.118072',
#               'street': {'id': 2039477, 'name': "On or near St John's Street"}},
#  'location_subtype': '',
#  'location_type': 'Force',
#  'month': '2025-05',
#  'outcome_status': None,
#  'persistent_id': ''}
# [{'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923315,
#   'location': {'latitude': '52.207966',
#                'longitude': '0.118072',
#                'street': {'id': 2039477,
#                           'name': "On or near St John's Street"}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923310,
#   'location': {'latitude': '52.211490',
#                'longitude': '0.135058',
#                'street': {'id': 2040164, 'name': 'On or near Acrefield Drive'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923517,
#   'location': {'latitude': '52.205622',
#                'longitude': '0.118912',
#                'street': {'id': 2039506, 'name': 'On or near Market Hill'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923065,
#   'location': {'latitude': '52.201889',
#                'longitude': '0.133456',
#                'street': {'id': 2040098, 'name': 'On or near Willis Road'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923053,
#   'location': {'latitude': '52.205622',
#                'longitude': '0.118912',
#                'street': {'id': 2039506, 'name': 'On or near Market Hill'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923025,
#   'location': {'latitude': '52.195780',
#                'longitude': '0.134129',
#                'street': {'id': 2040137,
#                           'name': 'On or near George Pateman Court'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923019,
#   'location': {'latitude': '52.199366',
#                'longitude': '0.127262',
#                'street': {'id': 2039865, 'name': 'On or near A1307'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922964,
#   'location': {'latitude': '52.208867',
#                'longitude': '0.133469',
#                'street': {'id': 2040122, 'name': 'On or near Auckland Road'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922921,
#   'location': {'latitude': '52.198400',
#                'longitude': '0.121524',
#                'street': {'id': 2039596,
#                           'name': 'On or near Further/higher Educational '
#                                   'Building'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922918,
#   'location': {'latitude': '52.213202',
#                'longitude': '0.136897',
#                'street': {'id': 2040253, 'name': 'On or near Petrol Station'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923210,
#   'location': {'latitude': '52.200443',
#                'longitude': '0.134338',
#                'street': {'id': 2040128, 'name': 'On or near Covent Garden'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923183,
#   'location': {'latitude': '52.199242',
#                'longitude': '0.135642',
#                'street': {'id': 2040181, 'name': 'On or near Felton Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923176,
#   'location': {'latitude': '52.204215',
#                'longitude': '0.121172',
#                'street': {'id': 2039607, 'name': 'On or near Shopping Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923114,
#   'location': {'latitude': '52.207109',
#                'longitude': '0.135185',
#                'street': {'id': 2040162, 'name': 'On or near Parking Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923146,
#   'location': {'latitude': '52.216579',
#                'longitude': '0.108615',
#                'street': {'id': 2039152,
#                           'name': 'On or near Canterbury Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923133,
#   'location': {'latitude': '52.205733',
#                'longitude': '0.128254',
#                'street': {'id': 2039927, 'name': 'On or near Elm Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922899,
#   'location': {'latitude': '52.204812',
#                'longitude': '0.121976',
#                'street': {'id': 2039658,
#                           'name': 'On or near Post Office Terrace'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922883,
#   'location': {'latitude': '52.204372',
#                'longitude': '0.119408',
#                'street': {'id': 2039519, 'name': 'On or near Wheeler Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922815,
#   'location': {'latitude': '52.203097',
#                'longitude': '0.121806',
#                'street': {'id': 2039662, 'name': 'On or near Downing Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922813,
#   'location': {'latitude': '52.213852',
#                'longitude': '0.125803',
#                'street': {'id': 2039742,
#                           'name': 'On or near Trafalgar Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922811,
#   'location': {'latitude': '52.201058',
#                'longitude': '0.126172',
#                'street': {'id': 2039849, 'name': 'On or near Regent Terrace'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922799,
#   'location': {'latitude': '52.196625',
#                'longitude': '0.122683',
#                'street': {'id': 2039675, 'name': 'On or near Brookside'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923209,
#   'location': {'latitude': '52.204215',
#                'longitude': '0.121172',
#                'street': {'id': 2039607, 'name': 'On or near Shopping Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923202,
#   'location': {'latitude': '52.217314',
#                'longitude': '0.108737',
#                'street': {'id': 2039100,
#                           'name': 'On or near Canterbury Close'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922767,
#   'location': {'latitude': '52.201421',
#                'longitude': '0.125173',
#                'street': {'id': 2039781,
#                           'name': 'On or near Further/higher Educational '
#                                   'Building'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922536,
#   'location': {'latitude': '52.203334',
#                'longitude': '0.129106',
#                'street': {'id': 2039881,
#                           'name': 'On or near Bus/coach Station'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922529,
#   'location': {'latitude': '52.208484',
#                'longitude': '0.141193',
#                'street': {'id': 2040382, 'name': 'On or near Harvest Way'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922499,
#   'location': {'latitude': '52.204372',
#                'longitude': '0.119408',
#                'street': {'id': 2039519, 'name': 'On or near Wheeler Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922400,
#   'location': {'latitude': '52.207515',
#                'longitude': '0.127125',
#                'street': {'id': 2039854, 'name': 'On or near Short Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922368,
#   'location': {'latitude': '52.214281',
#                'longitude': '0.122954',
#                'street': {'id': 2039672,
#                           'name': 'On or near Croft Holme Lane'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922349,
#   'location': {'latitude': '52.204812',
#                'longitude': '0.121976',
#                'street': {'id': 2039658,
#                           'name': 'On or near Post Office Terrace'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922333,
#   'location': {'latitude': '52.206593',
#                'longitude': '0.133474',
#                'street': {'id': 2040093, 'name': 'On or near Shopping Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922476,
#   'location': {'latitude': '52.198102',
#                'longitude': '0.112057',
#                'street': {'id': 2039245, 'name': 'On or near Summerfield'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922466,
#   'location': {'latitude': '52.213852',
#                'longitude': '0.125803',
#                'street': {'id': 2039742,
#                           'name': 'On or near Trafalgar Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922716,
#   'location': {'latitude': '52.208553',
#                'longitude': '0.131887',
#                'street': {'id': 2040056,
#                           'name': 'On or near Parsonage Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922329,
#   'location': {'latitude': '52.213202',
#                'longitude': '0.136897',
#                'street': {'id': 2040253, 'name': 'On or near Petrol Station'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922856,
#   'location': {'latitude': '52.208484',
#                'longitude': '0.141193',
#                'street': {'id': 2040382, 'name': 'On or near Harvest Way'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922868,
#   'location': {'latitude': '52.201889',
#                'longitude': '0.133456',
#                'street': {'id': 2040098, 'name': 'On or near Willis Road'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922708,
#   'location': {'latitude': '52.212778',
#                'longitude': '0.110952',
#                'street': {'id': 2039204,
#                           'name': 'On or near Mount Pleasant Walk'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922557,
#   'location': {'latitude': '52.211025',
#                'longitude': '0.113460',
#                'street': {'id': 2039346, 'name': 'On or near Honey Hill'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922377,
#   'location': {'latitude': '52.218365',
#                'longitude': '0.116312',
#                'street': {'id': 2039392, 'name': 'On or near Hale Avenue'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922739,
#   'location': {'latitude': '52.208141',
#                'longitude': '0.129804',
#                'street': {'id': 2039917,
#                           'name': 'On or near Brunswick Gardens'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923275,
#   'location': {'latitude': '52.207758',
#                'longitude': '0.138582',
#                'street': {'id': 2040317, 'name': 'On or near Occupation Road'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922430,
#   'location': {'latitude': '52.195544',
#                'longitude': '0.130984',
#                'street': {'id': 2039955,
#                           'name': 'On or near Further/higher Educational '
#                                   'Building'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923640,
#   'location': {'latitude': '52.204215',
#                'longitude': '0.121172',
#                'street': {'id': 2039607, 'name': 'On or near Shopping Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922325,
#   'location': {'latitude': '52.206447',
#                'longitude': '0.120517',
#                'street': {'id': 2039539, 'name': 'On or near Sidney Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922425,
#   'location': {'latitude': '52.204911',
#                'longitude': '0.132942',
#                'street': {'id': 2040082, 'name': 'On or near Parking Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923565,
#   'location': {'latitude': '52.210274',
#                'longitude': '0.136668',
#                'street': {'id': 2040213,
#                           'name': 'On or near Walnut Tree Avenue'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922305,
#   'location': {'latitude': '52.201568',
#                'longitude': '0.134319',
#                'street': {'id': 2040150, 'name': 'On or near Guest Road'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923597,
#   'location': {'latitude': '52.205622',
#                'longitude': '0.118912',
#                'street': {'id': 2039506, 'name': 'On or near Market Hill'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923436,
#   'location': {'latitude': '52.198102',
#                'longitude': '0.112057',
#                'street': {'id': 2039245, 'name': 'On or near Summerfield'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923586,
#   'location': {'latitude': '52.207111',
#                'longitude': '0.125627',
#                'street': {'id': 2039823, 'name': "On or near Pike's Walk"}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922648,
#   'location': {'latitude': '52.201421',
#                'longitude': '0.125173',
#                'street': {'id': 2039781,
#                           'name': 'On or near Further/higher Educational '
#                                   'Building'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922960,
#   'location': {'latitude': '52.204372',
#                'longitude': '0.119408',
#                'street': {'id': 2039519, 'name': 'On or near Wheeler Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922680,
#   'location': {'latitude': '52.206781',
#                'longitude': '0.118952',
#                'street': {'id': 2039508, 'name': 'On or near Gifford Place'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922620,
#   'location': {'latitude': '52.211055',
#                'longitude': '0.133764',
#                'street': {'id': 2040134, 'name': 'On or near Pentlands Close'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922845,
#   'location': {'latitude': '52.206593',
#                'longitude': '0.133474',
#                'street': {'id': 2040093, 'name': 'On or near Shopping Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923299,
#   'location': {'latitude': '52.212778',
#                'longitude': '0.110952',
#                'street': {'id': 2039204,
#                           'name': 'On or near Mount Pleasant Walk'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923290,
#   'location': {'latitude': '52.203995',
#                'longitude': '0.118380',
#                'street': {'id': 2039476, 'name': "On or near Bene't Street"}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923437,
#   'location': {'latitude': '52.205896',
#                'longitude': '0.131175',
#                'street': {'id': 2040012, 'name': 'On or near City Road'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922426,
#   'location': {'latitude': '52.207758',
#                'longitude': '0.138582',
#                'street': {'id': 2040317, 'name': 'On or near Occupation Road'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923274,
#   'location': {'latitude': '52.201990',
#                'longitude': '0.131510',
#                'street': {'id': 2040021, 'name': 'On or near Park/open Space'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923267,
#   'location': {'latitude': '52.199366',
#                'longitude': '0.127262',
#                'street': {'id': 2039865, 'name': 'On or near A1307'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922590,
#   'location': {'latitude': '52.195499',
#                'longitude': '0.120119',
#                'street': {'id': 2039490,
#                           'name': 'On or near Sports/recreation Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922282,
#   'location': {'latitude': '52.204911',
#                'longitude': '0.132942',
#                'street': {'id': 2040082, 'name': 'On or near Parking Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922582,
#   'location': {'latitude': '52.205622',
#                'longitude': '0.118912',
#                'street': {'id': 2039506, 'name': 'On or near Market Hill'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922549,
#   'location': {'latitude': '52.205344',
#                'longitude': '0.138832',
#                'street': {'id': 2040320,
#                           'name': 'On or near Vicarage Terrace'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922574,
#   'location': {'latitude': '52.205622',
#                'longitude': '0.118912',
#                'street': {'id': 2039506, 'name': 'On or near Market Hill'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922514,
#   'location': {'latitude': '52.196362',
#                'longitude': '0.125304',
#                'street': {'id': 2039798, 'name': 'On or near Coronation Mews'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923372,
#   'location': {'latitude': '52.206455',
#                'longitude': '0.121103',
#                'street': {'id': 2039587, 'name': 'On or near Nightclub'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922561,
#   'location': {'latitude': '52.208355',
#                'longitude': '0.105356',
#                'street': {'id': 2039036, 'name': 'On or near Cockcroft Place'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922548,
#   'location': {'latitude': '52.203247',
#                'longitude': '0.130463',
#                'street': {'id': 2040013, 'name': 'On or near Police Station'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922541,
#   'location': {'latitude': '52.204812',
#                'longitude': '0.121976',
#                'street': {'id': 2039658,
#                           'name': 'On or near Post Office Terrace'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923617,
#   'location': {'latitude': '52.198353',
#                'longitude': '0.112581',
#                'street': {'id': 2039309, 'name': 'On or near Newnham Road'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923237,
#   'location': {'latitude': '52.203629',
#                'longitude': '0.120719',
#                'street': {'id': 2039599,
#                           'name': 'On or near Corn Exchange Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923371,
#   'location': {'latitude': '52.218793',
#                'longitude': '0.119055',
#                'street': {'id': 2039474, 'name': 'On or near Bateson Road'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922326,
#   'location': {'latitude': '52.200225',
#                'longitude': '0.134986',
#                'street': {'id': 2040172, 'name': 'On or near Mill Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922439,
#   'location': {'latitude': '52.208867',
#                'longitude': '0.133469',
#                'street': {'id': 2040122, 'name': 'On or near Auckland Road'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922290,
#   'location': {'latitude': '52.203523',
#                'longitude': '0.124124',
#                'street': {'id': 2039682,
#                           'name': 'On or near Further/higher Educational '
#                                   'Building'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922483,
#   'location': {'latitude': '52.208057',
#                'longitude': '0.122042',
#                'street': {'id': 2039602, 'name': 'On or near Malcolm Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923380,
#   'location': {'latitude': '52.197361',
#                'longitude': '0.129786',
#                'street': {'id': 2039972, 'name': "On or near St Paul's Place"}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923560,
#   'location': {'latitude': '52.204911',
#                'longitude': '0.132942',
#                'street': {'id': 2040082, 'name': 'On or near Parking Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923537,
#   'location': {'latitude': '52.201421',
#                'longitude': '0.125173',
#                'street': {'id': 2039781,
#                           'name': 'On or near Further/higher Educational '
#                                   'Building'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923428,
#   'location': {'latitude': '52.201058',
#                'longitude': '0.126172',
#                'street': {'id': 2039849, 'name': 'On or near Regent Terrace'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923361,
#   'location': {'latitude': '52.204330',
#                'longitude': '0.117240',
#                'street': {'id': 2039430, 'name': 'On or near Shopping Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127922327,
#   'location': {'latitude': '52.206239',
#                'longitude': '0.138553',
#                'street': {'id': 2040307, 'name': 'On or near Petworth Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923358,
#   'location': {'latitude': '52.204215',
#                'longitude': '0.121172',
#                'street': {'id': 2039607, 'name': 'On or near Shopping Area'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923343,
#   'location': {'latitude': '52.202874',
#                'longitude': '0.117480',
#                'street': {'id': 2039465,
#                           'name': 'On or near Further/higher Educational '
#                                   'Building'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'anti-social-behaviour',
#   'context': '',
#   'id': 127923333,
#   'location': {'latitude': '52.205386',
#                'longitude': '0.124037',
#                'street': {'id': 2039776,
#                           'name': 'On or near Drummer Street Bus Station'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': None,
#   'persistent_id': ''},
#  {'category': 'bicycle-theft',
#   'context': '',
#   'id': 127920299,
#   'location': {'latitude': '52.207100',
#                'longitude': '0.119758',
#                'street': {'id': 2039561, 'name': 'On or near Supermarket'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Investigation complete; no suspect '
#                                  'identified',
#                      'date': '2025-05'},
#   'persistent_id': 'c9c71bc7ec1d584f93ab3a3e6825659b2dc2f0c0789a5e5bab162d10d4479330'},
#  {'category': 'bicycle-theft',
#   'context': '',
#   'id': 127921446,
#   'location': {'latitude': '52.202874',
#                'longitude': '0.117480',
#                'street': {'id': 2039465,
#                           'name': 'On or near Further/higher Educational '
#                                   'Building'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Investigation complete; no suspect '
#                                  'identified',
#                      'date': '2025-05'},
#   'persistent_id': 'e0d65c16f06a4bc98a398e1ca05779635f525ab3d2e2527ba64a0515b253f806'},
#  {'category': 'bicycle-theft',
#   'context': '',
#   'id': 127920854,
#   'location': {'latitude': '52.213852',
#                'longitude': '0.125803',
#                'street': {'id': 2039742,
#                           'name': 'On or near Trafalgar Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Investigation complete; no suspect '
#                                  'identified',
#                      'date': '2025-05'},
#   'persistent_id': '4297d711966c7d202db82e8f92ae3050e5be2c356963c117e32a3f7bd5bd02d2'},
#  {'category': 'bicycle-theft',
#   'context': '',
#   'id': 127920869,
#   'location': {'latitude': '52.208907',
#                'longitude': '0.118234',
#                'street': {'id': 2039501,
#                           'name': 'On or near Blackmoor Head Yard'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Investigation complete; no suspect '
#                                  'identified',
#                      'date': '2025-05'},
#   'persistent_id': '658ace41656636dbe6d93207327645a8677191fc3f8d005cf36338772b34407d'},
#  {'category': 'bicycle-theft',
#   'context': '',
#   'id': 127921267,
#   'location': {'latitude': '52.204372',
#                'longitude': '0.119408',
#                'street': {'id': 2039519, 'name': 'On or near Wheeler Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Investigation complete; no suspect '
#                                  'identified',
#                      'date': '2025-05'},
#   'persistent_id': '8210694100dd9273940c8b27d05c9a714417bfbc596e1ce5e6db1065d6263ab0'},
#  {'category': 'bicycle-theft',
#   'context': '',
#   'id': 127921003,
#   'location': {'latitude': '52.207875',
#                'longitude': '0.123658',
#                'street': {'id': 2039691, 'name': 'On or near Manor Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Investigation complete; no suspect '
#                                  'identified',
#                      'date': '2025-05'},
#   'persistent_id': '0b408919a3f533594df22821f8e1ff8a2ad2895291b1907764d0eea2c4321da3'},
#  {'category': 'bicycle-theft',
#   'context': '',
#   'id': 
},
#  {'category': 'violent-crime',
#   'context': '',
#   'id': 127916904,
#   'location': {'latitude': '52.204812',
#                'longitude': '0.121976',
#                'street': {'id': 2039658,
#                           'name': 'On or near Post Office Terrace'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Under investigation', 'date': '2025-05'},
#   'persistent_id': 'bad1c1e12a0fb898411b0acc86fb33a8ea727f49afeaeb2fb25b3214d7b27101'},
#  {'category': 'violent-crime',
#   'context': '',
#   'id': 127916973,
#   'location': {'latitude': '52.215475',
#                'longitude': '0.134488',
#                'street': {'id': 2040149, 'name': 'On or near Sandy Lane'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Under investigation', 'date': '2025-05'},
#   'persistent_id': '300911fb1d937823840705864e61ec43314813c1fb28eda3b68e07fafcd6beff'},
#  {'category': 'violent-crime',
#   'context': '',
#   'id': 127916992,
#   'location': {'latitude': '52.204812',
#                'longitude': '0.121976',
#                'street': {'id': 2039658,
#                           'name': 'On or near Post Office Terrace'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Under investigation', 'date': '2025-05'},
#   'persistent_id': '5b39e0429ea57450c54aee7e248fb6d1220203e9d743f2a83b42c7774a3bcf1f'},
#  {'category': 'violent-crime',
#   'context': '',
#   'id': 127917090,
#   'location': {'latitude': '52.201421',
#                'longitude': '0.125173',
#                'street': {'id': 2039781,
#                           'name': 'On or near Further/higher Educational '
#                                   'Building'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Unable to prosecute suspect',
#                      'date': '2025-06'},
#   'persistent_id': 'a75642899fee16bf7933e71775d6615a6c12c33dcad95e0c441a6656c01e393c'},
#  {'category': 'violent-crime',
#   'context': '',
#   'id': 127917370,
#   'location': {'latitude': '52.196760',
#                'longitude': '0.129172',
#                'street': {'id': 2039932, 'name': 'On or near Supermarket'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Local resolution', 'date': '2025-06'},
#   'persistent_id': '0b8b0849c9fcae05756e8ef3a8b1ec364ad2d9b24024aede17e7f9f46ffa0ea1'},
#  {'category': 'violent-crime',
#   'context': '',
#   'id': 127918864,
#   'location': {'latitude': '52.203523',
#                'longitude': '0.124124',
#                'street': {'id': 2039682,
#                           'name': 'On or near Further/higher Educational '
#                                   'Building'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Investigation complete; no suspect '
#                                  'identified',
#                      'date': '2025-05'},
#   'persistent_id': '44b1e4b5b5cda15ba89269964d084729adc5d97d3515938f1402738e7fde680c'},
#  {'category': 'violent-crime',
#   'context': '',
#   'id': 127917859,
#   'location': {'latitude': '52.207382',
#                'longitude': '0.124074',
#                'street': {'id': 2039765, 'name': 'On or near King Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Unable to prosecute suspect',
#                      'date': '2025-05'},
#   'persistent_id': 'def82b57a5d340e48daa4e256c61dfbae718827572143cbbe7443f5772fc2bf7'},
#  {'category': 'violent-crime',
#   'context': '',
#   'id': 127917722,
#   'location': {'latitude': '52.203355',
#                'longitude': '0.133453',
#                'street': {'id': 2040124, 'name': 'On or near Bradmore Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Under investigation', 'date': '2025-05'},
#   'persistent_id': 'a56b3198a13edf45e9578adf0ada92a968f4183a48fed818df0850f43a488ef2'},
#  {'category': 'other-crime',
#   'context': '',
#   'id': 127916392,
#   'location': {'latitude': '52.214281',
#                'longitude': '0.122954',
#                'street': {'id': 2039672,
#                           'name': 'On or near Croft Holme Lane'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Unable to prosecute suspect',
#                      'date': '2025-05'},
#   'persistent_id': '7e8fc104c2b1371d702bb19d1ef064d6f5829c5fcd71bca1bd1ade83a75500dd'},
#  {'category': 'other-crime',
#   'context': '',
#   'id': 127921141,
#   'location': {'latitude': '52.204083',
#                'longitude': '0.134469',
#                'street': {'id': 2040136, 'name': 'On or near Broad Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Unable to prosecute suspect',
#                      'date': '2025-06'},
#   'persistent_id': '5c85a6b3ff71ef3d447889d1e1f5cf13ed8453e43e224f455bab877403b4e5d4'},
#  {'category': 'other-crime',
#   'context': '',
#   'id': 127919650,
#   'location': {'latitude': '52.206447',
#                'longitude': '0.120517',
#                'street': {'id': 2039539, 'name': 'On or near Sidney Street'}},
#   'location_subtype': '',
#   'location_type': 'Force',
#   'month': '2025-05',
#   'outcome_status': {'category': 'Local resolution', 'date': '2025-05'},
#   'persistent_id': 'da814f6c5f9b5556cc2661b20f5e2cff6b4cd2f9b0ee382bc367575a1c372415'}]

# %% [markdown]
# Each dictionary object corresponds to a reported crime.

# %% [markdown]
# ### Task
#
# Produce a bar chart of the number of reports in different categories. Run your program for different parts of Cambridge, starting with the area around your college, and for different months and years.
#
# #### Hints
#
# Create an empty dictionary, which will eventually map the report category to the number of incidents:

# %%
categories_freq = {}

# %% [markdown]
# Iterate over all reports in the list, and extract the category string from each report. If the category string (the 'key') is already in the dictionary increment the associated counter. Otherwise add the key to the dictionary, and associate the value 1.

# %%
# Iterate over all reports
for report in crime_data:
    # Get category type
    category = report['category']
    
    if category in categories_freq:
        categories_freq[category] += 1
    else:
        categories_freq[category] = 1

pprint.pprint(categories_freq)
# Out:
# {'anti-social-behaviour': 178,
#  'bicycle-theft': 86,
#  'burglary': 18,
#  'criminal-damage-arson': 58,
#  'drugs': 20,
#  'other-crime': 6,
#  'other-theft': 100,
#  'possession-of-weapons': 12,
#  'public-order': 82,
#  'robbery': 14,
#  'shoplifting': 226,
#  'theft-from-the-person': 36,
#  'vehicle-crime': 42,
#  'violent-crime': 224}

# %% [markdown]
# The crime categories are the dictionary keys, which can be extracted using
# ```python
# list(categories_freq.keys())
# ```

# %% [markdown]
# When adding the tick labels (crime categories), it may be necessary to rotate the labels, e.g.:
# ```python
# plt.xticks(x_pos, categories, rotation='vertical')
# ```

# %% [markdown]
# ### Extensions (optional)
#
#
# 1. Probe the retrieved data to build a set of all crime categories in the data set.
# 2. Explore the temporal (time) aspect of the data. Thinks of ways to represent the change in reported incident
#    types over time.
# 3. Explore what other data you can retrieve from https://data.police.uk/docs/.

# %% [markdown]
# ### Solution
#
# There are many ways this exercise could be programmed, and there is some choice in data structures.
#
# Build (a) a list of crime categories and (b) the number of reports in each category:

# %%
# Empty dictionary
categories_freq = {}

for report in crime_data:
    # Get category type
    category = report['category']
    
    if category in categories_freq:
        categories_freq[category] += 1
    else:
        categories_freq[category] = 1

categories = categories_freq.keys()
frequencies = categories_freq.values()

print(categories)
print(frequencies)
# Out:
# dict_keys(['anti-social-behaviour', 'bicycle-theft', 'burglary', 'criminal-damage-arson', 'drugs', 'other-theft', 'possession-of-weapons', 'public-order', 'robbery', 'shoplifting', 'theft-from-the-person', 'vehicle-crime', 'violent-crime', 'other-crime'])
# dict_values([89, 43, 9, 29, 10, 50, 6, 41, 7, 113, 18, 21, 112, 3])

# %% [markdown]
# Produce a bar chart:

# %%
# Create an array with the position of each bar along the x-axis
x_pos = np.arange(len(categories_freq))

plt.bar(x_pos, frequencies, align='center', alpha=0.7)
plt.xticks(x_pos, categories, rotation='vertical')
plt.ylabel('Frequency')
plt.title('Crime Categories Frequency in Cambridge City Centre (May 2025)')
# Out:
# Text(0.5, 1.0, 'Crime Categories Frequency in Cambridge City Centre (May 2025)')
